# %% [markdown]
# **Install Libraries**

# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.3/112.6 GB disk)

# %% [markdown]
# **Dataset Preparation**

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="u8XcNJ45hk51Vsdk1Umr")
project = rf.workspace("fadwas-workspace-2eqsg").project("final-dataset-project-igccm")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# **Model Training**

# %%
# !yolo train model=yolov8s.pt data="/content/final-dataset(project)-1/data.yaml" epochs=40 imgsz=640
# Out:
# ...
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Testing&Prediction**

# %%
# !yolo predict model="/content/runs/detect/train/weights/best.pt" source="/content/final-dataset(project)-1/test/images"
# Out:
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/522 /content/final-dataset(project)-1/test/images/16065871-students-sitting-in-an-exam-hall-doing-an-exam-in-university_webp_jpg.rf.1199772e8d7ea5987b0b87097a1af83e.jpg: 640x640 1 Hand-Normalmove, 1 Non-Cheating, 16.2ms
# image 2/522 /content/final-dataset(project)-1/test/images/360_F_265671352_FY4xJvzpl97PuQDsEu7egMKloosHwg31_webp_jpg.rf.4f7901abeee72642e388a13af1423555.jpg: 640x640 1 Cheating, 2 Non-Cheatings, 16.3ms
# image 3/522 /content/final-dataset(project)-1/test/images/360_F_712769107_kQvGkx1zNBIPpD5yVQXRvZ9zyVW1GqqF_webp_jpg.rf.639a3ec48607b4504785c4bb37d48a1e.jpg: 640x640 2 Non-Cheatings, 16.3ms
# image 4/522 /content/final-dataset(project)-1/test/images/WIN_20230414_16_48_25_Pro_jpg.rf.387915d706bfb1dd154010dd917b48a1.jpg: 640x640 1 Cheating, 7 Hand-Normalmoves, 3 Non-Cheatings, 16.2ms
# ...

# %%
# !yolo predict model="/content/runs/detect/train/weights/best.pt" source="/content/teat(4).jpg"
# Out:
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/teat(4).jpg: 448x640 1 Cheating, 3 Non-Cheatings, 48.5ms
# Speed: 3.2ms preprocess, 48.5ms inference, 16.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict-2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model="/content/runs/detect/train/weights/best.pt" source="/content/test(1).jpg"
# Out:
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/test(1).jpg: 448x640 1 Cheating, 72.2ms
# Speed: 7.3ms preprocess, 72.2ms inference, 23.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict-3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model="/content/runs/detect/train/weights/best.pt" source="/content/test(2).jpg"
# Out:
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/test(2).jpg: 448x640 2 Cheatings, 2 Non-Cheatings, 47.6ms
# Speed: 3.7ms preprocess, 47.6ms inference, 17.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict-4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model="/content/runs/detect/train/weights/best.pt" source="/content/test(3).jpg"
# Out:
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/test(3).jpg: 448x640 3 Cheatings, 47.2ms
# Speed: 3.4ms preprocess, 47.2ms inference, 17.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict-5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model="/content/runs/detect/train/weights/best.pt" source="/content/WhatsApp Image 2026-07-14 at 1.45.24 AM.jpeg"
# Out:
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/WhatsApp Image 2026-07-14 at 1.45.24 AM.jpeg: 448x640 2 Cheatings, 82.2ms
# Speed: 7.4ms preprocess, 82.2ms inference, 21.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict-10
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **Model_Evaluation**

# %%
from ultralytics import YOLO
model = YOLO("/content/runs/detect/train/weights/best.pt")
results = model.val()
# Out:
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2231.6±781.0 MB/s, size: 54.2 KB)
# val: Scanning /content/final-dataset(project)-1/valid/labels.cache... 521 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 521/521 87.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 33/33 3.4it/s 9.7s
#                    all        521       6685      0.941      0.949      0.974      0.785
#               Cheating        322        471      0.914      0.942      0.975      0.847
#        Hand-Normalmove        494       3676      0.958      0.966      0.982      0.723
#    Hand-Suspiciousmove        297        487       0.92      0.899      0.948      0.667
#           Non-Cheating        393       2051      0.974      0.989      0.992      0.901
# ...

# %% [markdown]
# **Connect to drive to save trained model**

# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p "/content/drive/MyDrive/NTI_Project"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp "/content/runs/detect/train/weights/best.pt" "/content/drive/MyDrive/NTI_Project/"

# %%
# !cp "/content/final-dataset(project)-1/data.yaml" "/content/drive/MyDrive/NTI_Project/"
